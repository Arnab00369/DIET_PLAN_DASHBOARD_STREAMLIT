# %%
import pandas as pd

# ==========================================================
# STEP 1 — Load Your Indian Food Dataset
# ==========================================================
df = pd.read_csv("Indian_Food_Nutrition_Processed.csv")
df = pd.read_csv("food.csv")
df = pd.read_csv("nutrition.csv")
# ==========================================================
# STEP 2 — Basic Cleanup
# ==========================================================
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df = df.loc[:, ~df.columns.duplicated(keep='first')]
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.dropna(axis=1, how='all', inplace=True)

df['source'] = 'Indian_Food_Dataset'

# ==========================================================
# STEP 3 — Detect & Clean Nutrition Columns
# ==========================================================
# Try to find possible nutrition columns automatically
def find_col(possible_names):
    for col in df.columns:
        for name in possible_names:
            if name in col.lower():
                return col
    return None

cal_col = find_col(['calorie', 'energy'])
protein_col = find_col(['protein'])
fat_col = find_col(['fat'])
carb_col = find_col(['carb', 'carbohydrate'])

found_cols = [cal_col, protein_col, fat_col, carb_col]
found_cols = [c for c in found_cols if c is not None]

# Convert to numeric
for col in found_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Fill missing numeric values
df[found_cols] = df[found_cols].fillna(df[found_cols].median())

# Rename them uniformly for consistency
rename_map = {}
if cal_col: rename_map[cal_col] = 'calories'
if protein_col: rename_map[protein_col] = 'protein'
if fat_col: rename_map[fat_col] = 'fat'
if carb_col: rename_map[carb_col] = 'carbs'
df.rename(columns=rename_map, inplace=True)

# ==========================================================
# STEP 4 — Add Derived Columns
# ==========================================================
if 'name' not in df.columns:
    df['name'] = df.iloc[:, 0]
df['name'] = df['name'].astype(str).str.title()

allergens = {
    'is_allergen_peanuts': ['peanut', 'groundnut'],
    'is_allergen_dairy': ['milk', 'cheese', 'paneer', 'curd', 'butter', 'ghee'],
    'is_allergen_eggs': ['egg'],
    'is_allergen_gluten': ['wheat', 'barley', 'rye', 'bread', 'roti', 'chapati'],
    'is_allergen_seafood': ['fish', 'prawn', 'shrimp', 'crab'],
    'is_allergen_soy': ['soy', 'soya'],
    'is_allergen_treenuts': ['almond', 'cashew', 'walnut', 'pistachio', 'hazelnut']
}

for col, keywords in allergens.items():
    df[col] = df['name'].str.contains('|'.join(keywords), case=False, na=False)

# Use only existing numeric columns for suitability
if 'carbs' in df.columns:
    df['suitable_diabetes'] = df['carbs'] < df['carbs'].median()
else:
    df['suitable_diabetes'] = False

if 'fat' in df.columns:
    df['suitable_hypertension'] = df['fat'] < df['fat'].median()
else:
    df['suitable_hypertension'] = False

df['is_veg'] = ~df['name'].str.contains(
    'chicken|mutton|fish|egg|beef|prawn|crab|meat', case=False, na=False
)

# ==========================================================
# STEP 5 — Final Dataset
# ==========================================================
final_cols = (
    ['source', 'name']
    + [col for col in ['calories', 'protein', 'fat', 'carbs'] if col in df.columns]
    + ['is_veg']
    + list(allergens.keys())
    + ['suitable_diabetes', 'suitable_hypertension']
)
df_final = df[final_cols].copy()

# ==========================================================
# STEP 6 — Save & Display
# ==========================================================
df_final.to_csv("Cleaned_Indian_Food_Dataset.csv", index=False)
print("✅ Cleaned and organized Indian food dataset created successfully!")
print("Shape:", df_final.shape)
display(df_final.head(20))
# Out:
# ✅ Cleaned and organized Indian food dataset created successfully!
# Shape: (1014, 16)
#                  source                                       name  calories  \
# 0   Indian_Food_Dataset                       Hot Tea (Garam Chai)     16.14
# 1   Indian_Food_Dataset                             Instant Coffee     23.16
# 2   Indian_Food_Dataset                             Espreso Coffee     51.54
# 3   Indian_Food_Dataset                                   Iced Tea     10.34
# 4   Indian_Food_Dataset                Raw Mango Drink (Aam Panna)     35.92
# 5   Indian_Food_Dataset            Fruit Punch (With Fresh Juices)     36.12
# 6   Indian_Food_Dataset                Fruit Punch (With Squashes)     23.13
# 7   Indian_Food_Dataset                                   Lemonade     20.80
# 8   Indian_Food_Dataset                                  Lem-O-Gin     21.52
# 9   Indian_Food_Dataset  Cumin Infused Water (Jeere/Zeere Ka Pani)      9.09
# 10  Indian_Food_Dataset                           Coco Pine Cooler     32.75
# 11  Indian_Food_Dataset                              Summer Cooler     22.43
# 12  Indian_Food_Dataset                                  Hot Cocoa     90.10
# 13  Indian_Food_Dataset                 Cold Coffee With Ice Cream     67.85
# 14  Indian_Food_Dataset          Banana Milkshake (Kele Milkshake)     65.31
# 15  Indian_Food_Dataset            Mango Milkshake (Aam Milkshake)     56.90
# 16  Indian_Food_Dataset     Pineapple Milkshake (Ananas Milkshake)     55.72
# 17  Indian_Food_Dataset       Orange Milkshake (Narangi Milkshake)     57.42
# 18  Indian_Food_Dataset                                    Egg Nog     97.14
# 19  Indian_Food_Dataset                 Sweet Lassi (Meethi Lassi)     35.66
#
#     protein   fat  carbs  is_veg  is_allergen_peanuts  is_allergen_dairy  \
# 0      0.39  0.53   2.58    True                False              False
# 1      0.64  0.75   3.65    True                False              False
# 2      1.75  2.14   6.62    True                False              False
# 3      0.03  0.01   2.70    True                False              False
# 4      0.16  0.03   9.05    True                False              False
# 5      0.14  0.03   9.38    True                False              False
# 6      0.07  0.02   5.99    True                False              False
# 7      0.03  0.01   5.48    True                False              False
# 8      0.08  0.03   5.55    True                False              False
# 9      0.17  0.11   1.86    True                False              False
# 10     0.56  1.00   5.72    True                False              False
# 11     0.37  0.04   5.43    True                False              False
# 12     3.36  4.56   9.23    True                False              False
# 13     1.57  2.11  11.24    True                False              False
# 14     1.84  2.37   9.15    True                False               True
# 15     1.73  2.35   7.23    True                False               True
# 16     1.66  2.23   7.62    True                False               True
# 17     1.86  2.52   7.11    True                False               True
# 18     4.78  5.11   8.15   False                False              False
# 19     1.29  0.68   6.51    True                False              False
#
#     is_allergen_eggs  is_allergen_gluten  is_allergen_seafood  \
# 0              False               False                False
# 1              False               False                False
# 2              False               False                False
# 3              False               False                False
# 4              False               False                False
# 5              False               False                False
# 6              False               False                False
# 7              False               False                False
# 8              False               False                False
# 9              False               False                False
# 10             False               False                False
# 11             False               False                False
# 12             False               False                False
# 13             False               False                False
# 14             False               False                False
# 15             False               False                False
# 16             False               False                False
# 17             False               False                False
# 18              True               False                False
# 19             False               False                False
#
#     is_allergen_soy  is_allergen_treenuts  suitable_diabetes  \
# 0             False                 False               True
# 1             False                 False               True
# 2             False                 False               True
# 3             False                 False               True
# 4             False                 False               True
# 5             False                 False               True
# 6             False                 False               True
# 7             False                 False               True
# 8             False                 False               True
# 9             False                 False               True
# 10            False                 False               True
# 11            False                 False               True
# 12            False                 False               True
# 13            False                 False               True
# 14            False                 False               True
# 15            False                 False               True
# 16            False                 False               True
# 17            False                 False               True
# 18            False                 False               True
# 19            False                 False               True
#
#     suitable_hypertension
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                    True
# 6                    True
# 7                    True
# 8                    True
# 9                    True
# 10                   True
# 11                   True
# 12                   True
# 13                   True
# 14                   True
# 15                   True
# 16                   True
# 17                   True
# 18                   True
# 19                   True
